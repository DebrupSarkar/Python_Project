# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('stroke_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29065 entries, 0 to 29064
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             29065 non-null  object
#  1   age                29065 non-null  float64
#  2   hypertension       29065 non-null  int64
#  3   heart_disease      29065 non-null  int64
#  4   ever_married       29065 non-null  object
#  5   work_type          29065 non-null  object
#  6   Residence_type     29065 non-null  object
#  7   avg_glucose_level  29065 non-null  float64
#  8   bmi                29065 non-null  float64
#  9   smoking_status     29065 non-null  object
#  10  stroke             29065 non-null  int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 2.4+ MB

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  58.0             1              0          Yes        Private
# 1  Female  70.0             0              0          Yes        Private
# 2  Female  52.0             0              0          Yes        Private
# 3  Female  75.0             0              1          Yes  Self-employed
# 4  Female  32.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban              87.96  39.2     never smoked       0
# 1          Rural              69.04  35.9  formerly smoked       0
# 2          Urban              77.59  17.7  formerly smoked       0
# 3          Rural             243.53  27.0     never smoked       0
# 4          Rural              77.67  32.3           smokes       0

# %%
#data cleaning

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
#no null values !!

# %%
df.sort_values('bmi')
# Out:
#        gender   age  hypertension  heart_disease ever_married work_type  \
# 17829    Male  39.0             0              0          Yes   Private
# 9435   Female  71.0             0              0          Yes  Govt_job
# 18295    Male  49.0             0              0          Yes   Private
# 1325     Male  40.0             0              0          Yes   Private
# 24784  Female  44.0             0              0          Yes   Private
# ...       ...   ...           ...            ...          ...       ...
# 484    Female  23.0             1              0           No   Private
# 20539  Female  34.0             0              0           No   Private
# 23306  Female  47.0             1              0          Yes   Private
# 28869    Male  78.0             1              0          Yes   Private
# 2682     Male  38.0             1              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi smoking_status  stroke
# ...

# %%
df['AGE GROUP']=df['age'] //10

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  58.0             1              0          Yes        Private
# 1  Female  70.0             0              0          Yes        Private
# 2  Female  52.0             0              0          Yes        Private
# 3  Female  75.0             0              1          Yes  Self-employed
# 4  Female  32.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke  AGE GROUP
# 0          Urban              87.96  39.2     never smoked       0        5.0
# 1          Rural              69.04  35.9  formerly smoked       0        7.0
# 2          Urban              77.59  17.7  formerly smoked       0        5.0
# 3          Rural             243.53  27.0     never smoked       0        7.0
# 4          Rural              77.67  32.3           smokes       0        3.0

# %%
sns.barplot(x='AGE GROUP' , y='stroke' ,data=df ,palette= 'mako')
# Out:
# <AxesSubplot:xlabel='AGE GROUP', ylabel='stroke'>

# %%
## implies probability of stroke more in age group 80-90 yrs

# %%
df.sort_values('bmi' , inplace=True)

# %%
df.tail()
# Out:
#        gender   age  hypertension  heart_disease ever_married work_type  \
# 484    Female  23.0             1              0           No   Private
# 20539  Female  34.0             0              0           No   Private
# 23306  Female  47.0             1              0          Yes   Private
# 28869    Male  78.0             1              0          Yes   Private
# 2682     Male  38.0             1              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi smoking_status  stroke  \
# 484            Urban              70.03  78.0         smokes       0
# 20539          Urban             199.13  80.1   never smoked       0
# 23306          Urban             238.47  82.7   never smoked       0
# 28869          Rural             135.73  89.0   never smoked       0
# 2682           Rural              56.90  92.0   never smoked       0
#
#        AGE GROUP
# 484          2.0
# 20539        3.0
# 23306        4.0
# 28869        7.0
# 2682         3.0

# %%
## bmi group calculation

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['smoking_status'].unique()
# Out:
# array(['smokes', 'never smoked', 'formerly smoked'], dtype=object)

# %%
label_encoder = LabelEncoder()

# %%
df['smoking_status_label'] = label_encoder.fit_transform(df['smoking_status'])

# %%
df['smoking_status_label'].unique()
# Out:
# array([2, 1, 0])

# %%
#2 is for smokes #1 for never smoked # 0 for formerly smoked

# %%
df.head()
# Out:
#        gender   age  hypertension  heart_disease ever_married work_type  \
# 17829    Male  39.0             0              0          Yes   Private
# 9435   Female  71.0             0              0          Yes  Govt_job
# 18295    Male  49.0             0              0          Yes   Private
# 1325     Male  40.0             0              0          Yes   Private
# 24784  Female  44.0             0              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi smoking_status  stroke  \
# 17829          Rural              75.90  10.1         smokes       0
# 9435           Rural              59.13  10.8   never smoked       0
# 18295          Urban              81.50  11.0   never smoked       0
# 1325           Rural              60.96  11.5   never smoked       0
# 24784          Urban             162.04  12.5   never smoked       0
#
#        AGE GROUP  smoking_status_label
# 17829        3.0                     2
# ...

# %%
df.drop('smoking_status' ,axis=1)
# Out:
#        gender   age  hypertension  heart_disease ever_married work_type  \
# 17829    Male  39.0             0              0          Yes   Private
# 9435   Female  71.0             0              0          Yes  Govt_job
# 18295    Male  49.0             0              0          Yes   Private
# 1325     Male  40.0             0              0          Yes   Private
# 24784  Female  44.0             0              0          Yes   Private
# ...       ...   ...           ...            ...          ...       ...
# 484    Female  23.0             1              0           No   Private
# 20539  Female  34.0             0              0           No   Private
# 23306  Female  47.0             1              0          Yes   Private
# 28869    Male  78.0             1              0          Yes   Private
# 2682     Male  38.0             1              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi  stroke  AGE GROUP  \
# ...

# %%
df.drop('age' , axis=1)
# Out:
#        gender  hypertension  heart_disease ever_married work_type  \
# 17829    Male             0              0          Yes   Private
# 9435   Female             0              0          Yes  Govt_job
# 18295    Male             0              0          Yes   Private
# 1325     Male             0              0          Yes   Private
# 24784  Female             0              0          Yes   Private
# ...       ...           ...            ...          ...       ...
# 484    Female             1              0           No   Private
# 20539  Female             0              0           No   Private
# 23306  Female             1              0          Yes   Private
# 28869    Male             1              0          Yes   Private
# 2682     Male             1              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi smoking_status  stroke  \
# 17829          Rural              75.90  10.1         smokes       0
# ...

# %%
sns.barplot(x='smoking_status_label' ,y='stroke' ,data=df)
# Out:
# <AxesSubplot:xlabel='smoking_status_label', ylabel='stroke'>

# %%
#possibility of stroke directly linked with smoking history 
#0= formerly smoked, greatest probability
#1=never smoked , least possibility
#2=smokes now , medium probability

# %%
plt.figure(figsize=(10, 4), dpi=100)
sns.violinplot(x='smoking_status_label' ,y='stroke' ,data=df , hue ='gender')
# Out:
# <AxesSubplot:xlabel='smoking_status_label', ylabel='stroke'>

# %%
#inference ??

# %%
## trying to find relationship between hypertension and stroke probability

# %%
sns.barplot(x='hypertension' , y='stroke' ,data=df , palette='viridis')
# Out:
# <AxesSubplot:xlabel='hypertension', ylabel='stroke'>

# %%
## clear implication that people having hypertension more probable to suffer from stroke

# %%
#heart disease vs stroke

# %%
sns.barplot(x='heart_disease' , y='stroke' ,data=df , palette='viridis')
# Out:
# <AxesSubplot:xlabel='heart_disease', ylabel='stroke'>

# %%
## heart disease increases stroke risk

# %%
## finding intersection of two col heart disease and hypertension

# %%
df['combined'] =df['hypertension'] * df['heart_disease']

# %%
df['combined'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
## creating a new column combined with data from col hypertension and heartdisease 
## 1 where a patient has both , 0 otherwise 
## combined condition vs single condition

# %%
sns.barplot(x=df['combined'], y= df['stroke'] , palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='combined', ylabel='stroke'>

# %%
## where both heart disease , hypertension present probability is more than in individual cases

# %%
df.sort_values('bmi')
# Out:
#        gender   age  hypertension  heart_disease ever_married work_type  \
# 17829    Male  39.0             0              0          Yes   Private
# 9435   Female  71.0             0              0          Yes  Govt_job
# 18295    Male  49.0             0              0          Yes   Private
# 1325     Male  40.0             0              0          Yes   Private
# 24784  Female  44.0             0              0          Yes   Private
# ...       ...   ...           ...            ...          ...       ...
# 484    Female  23.0             1              0           No   Private
# 20539  Female  34.0             0              0           No   Private
# 23306  Female  47.0             1              0          Yes   Private
# 28869    Male  78.0             1              0          Yes   Private
# 2682     Male  38.0             1              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi smoking_status  stroke  \
# ...

# %%
df.drop('age' , axis=1)
# Out:
#        gender  hypertension  heart_disease ever_married work_type  \
# 17829    Male             0              0          Yes   Private
# 9435   Female             0              0          Yes  Govt_job
# 18295    Male             0              0          Yes   Private
# 1325     Male             0              0          Yes   Private
# 24784  Female             0              0          Yes   Private
# ...       ...           ...            ...          ...       ...
# 484    Female             1              0           No   Private
# 20539  Female             0              0           No   Private
# 23306  Female             1              0          Yes   Private
# 28869    Male             1              0          Yes   Private
# 2682     Male             1              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi smoking_status  stroke  \
# 17829          Rural              75.90  10.1         smokes       0
# ...

# %%
## exploring the relationship between marital status and stroke probability

# %%
sns.barplot(x=df['ever_married'], y= df['stroke'] , palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='ever_married', ylabel='stroke'>

# %%
## married people more likely to suffer from stroke

# %%
## exploring relationship between work type and stroke 
## is any particular work type more probable to suffer from stroke ??

# %%
plt.figure(dpi=100)
sns.barplot(x=df['work_type'], y= df['stroke'] , palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='work_type', ylabel='stroke'>

# %%
##  people  with govt job least likely to suffer a stroke due to job and financial stability ?? 
## self employed people most likely to suffer from stroke due to stress relaed issues 
## private sector standing in between these two

# %%
  ## exploring the relationship between residence type and stroke

# %%
plt.figure(dpi=100)
sns.barplot(x=df['Residence_type'], y= df['stroke'] , palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='Residence_type', ylabel='stroke'>

# %%
##people living in rural areas at slightly lower risk

# %%
## variation across genders and work type

# %%
plt.figure(dpi=100)
sns.barplot(x=df['work_type'], y= df['stroke'] , palette = 'viridis' , hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='work_type', ylabel='stroke'>

# %%
 ## among gender and worktype men more likely to suffer from stroke in every work type 
##other than govt job where females are at greater risk

# %%
sns.barplot(x='gender' , y='stroke' , data=df , palette ='viridis')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='stroke'>

# %%
## men at significantly greater risk than females

# %%
## trying to establish relation between smoking status and gender with stroke possibility

# %%
plt.figure(dpi=100)
sns.barplot(x='smoking_status' , y='stroke' ,data=df , palette='viridis' , hue='gender')
# Out:
# <AxesSubplot:xlabel='smoking_status', ylabel='stroke'>

# %%
## females at lesser risk than men in general , but in case of never smoked , females at gretaer risk.
## prob of stroke more in former smokers than current active smokers is a notable conclusion

# %%
sns.barplot(x='heart_disease' , y='stroke' ,data=df , palette='rocket' , hue='gender')
# Out:
# <AxesSubplot:xlabel='heart_disease', ylabel='stroke'>

# %% [markdown]
# ### From the above graph, we can predict that women with heart diseases have higher chances of stroke than men with heart diseases.

# %%
sns.barplot(x='Residence_type', y= 'stroke' , data=df, palette='rocket' , hue='gender')
# Out:
# <AxesSubplot:xlabel='Residence_type', ylabel='stroke'>

# %% [markdown]
# ### From the above graph we can predict that men living in urban resisdence have the highest chance of stroke.

# %%
sns.barplot(x='work_type', y= 'stroke' , data=df, palette='rocket' , hue='gender')
# Out:
# <AxesSubplot:xlabel='work_type', ylabel='stroke'>

# %% [markdown]
# ### From the above graph we can predict that men who are self-employed have the higest chances of stroke followed by self employeed women.

# %%
sns.barplot(x='hypertension', y= 'stroke' , data=df, palette='rocket' , hue='gender')
# Out:
# <AxesSubplot:xlabel='hypertension', ylabel='stroke'>

# %% [markdown]
# ### From the above graph we can predict that women with hypertension have higher chances of stroke than men with hypertension. But men without hypertension have higher chances of stroke than wowen without hypertenstion.

# %%
#20.2.21

# %%
df['bmi group']=df['bmi']//10

# %%
df.head()
# Out:
#        gender   age  hypertension  ...  smoking_status_label combined bmi group
# 17829    Male  39.0             0  ...                     2        0       1.0
# 9435   Female  71.0             0  ...                     1        0       1.0
# 18295    Male  49.0             0  ...                     1        0       1.0
# 1325     Male  40.0             0  ...                     1        0       1.0
# 24784  Female  44.0             0  ...                     1        0       1.0
#
# [5 rows x 15 columns]

# %%
sns.barplot(y='bmi group',x='AGE GROUP',data=df,hue='gender')

# %%
sns.barplot(x='bmi group',y='avg_glucose_level',data=df,hue='gender')

# %%
sns.barplot(x='bmi group',='age',data=df,hue='stroke')

# %%
sns.kdeplot(x='bmi group',data=df,hue='AGE GROUP',palette='rocket')

# %%
sns.kdeplot(x='AGE GROUP',data=df,hue='bmi group',palette='rocket')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
